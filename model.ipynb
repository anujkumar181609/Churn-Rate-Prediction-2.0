# %%
#importing libraries
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#load the dataset
df= pd.read_csv('Churn Rate Dataset.csv')

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   str
#  1   gender            7043 non-null   str
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   str
#  4   Dependents        7043 non-null   str
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   str
#  7   MultipleLines     7043 non-null   str
#  8   InternetService   7043 non-null   str
#  9   OnlineSecurity    7043 non-null   str
#  10  OnlineBackup      7043 non-null   str
#  11  DeviceProtection  7043 non-null   str
#  12  TechSupport       7043 non-null   str
#  13  StreamingTV       7043 non-null   str
#  14  StreamingMovies   7043 non-null   str
#  15  Contract          7043 non-null   str
#  16  PaperlessBilling  7043 non-null   str
#  17  PaymentMethod     7043 non-null   str
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   str
#  20  Churn             7043 non-null   str
# dtypes: float64(1), int64(2), str(18)
# memory usage: 1.9 MB

# %%
#removing customer id
df.drop('customerID', axis=1,  inplace=True)

# %%
#total charges from object to float
df['TotalCharges']= df['TotalCharges'].replace(' ',0).astype(float)

# %%
#Churn Rate Distribution
sns.countplot(x='Churn', data=df)
plt.title('Churn Rate Distribution')
plt.show()

# %%
#Contract type vs Churn Rate
sns.countplot(x='Contract',hue='Churn', data=df)
plt.title('Contract Type vs Churn Rate')
plt.show()

# %%
#Payment Method vs Churn Rate
sns.countplot(x='PaymentMethod', hue='Churn', data=df)
plt.title('Payment Method vs Churn Rate')
plt.xticks(rotation=45)
plt.show()

# %%
#Internet service vs Churn Rate
sns.countplot(x='InternetService', hue='Churn',data=df)
plt.title('Internet Service vs Churn Rate')
plt.show()

# %%
#Online security vs Churn Rate
sns.countplot(x='OnlineSecurity', hue='Churn',data=df)
plt.title('Online Security vs Churn Rate')
plt.show()

# %%
#Tenure vs Churn Rate
sns.boxplot(x='tenure', y='Churn', data=df)
plt.title('Tenure vs Churn Rate')
plt.show()

# %%
#Monthly Charges vs Churn Rate
sns.boxplot(x='MonthlyCharges', y='Churn', data=df)
plt.title('Monthly Charges vs Churn Rate')
plt.show()

# %% [markdown]
# EDA Summary:
#
# Churn dataset is imbalanced.
#
# Customers with month-to-month contracts are more likely to churn.
#
# Low tenure customers have higher churn probability.
#
# Higher monthly charges correlate with churn.
#
# Certain payment methods show higher churn behavior.

# %%
#mapping churn to binary
df['Churn'] = df['Churn'].map({'Yes':1, 'No':0})

# %%
#splitting the dataset into features and target variable
X= df.drop('Churn', axis=1)
y= df['Churn']

# %%
#importing train test split
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test= train_test_split(X,y, random_state=124, test_size=0.15,shuffle=True)

# %%
#importing the models
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

# %%
num_cols=['tenure','MonthlyCharges','TotalCharges']
cat_cols= [col for col in X.columns if col not in num_cols]

# %%
#importing libraries for preprocessing
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder

# %%
#pipeline for numerical features model
num_pipeline= ColumnTransformer([
    ('num', StandardScaler(), num_cols),
    ('cat', OneHotEncoder(handle_unknown='ignore'), cat_cols)
])

# %%
#pipeline for tree models
tree_pipeline= ColumnTransformer([
    ('num' ,'passthrough', num_cols),
    ('cat', OneHotEncoder(handle_unknown='ignore'), cat_cols)
])

# %%
#training models

#Logistic Regression
lr_pipeline= Pipeline([
    ('preprocessor', num_pipeline),
    ('model', LogisticRegression())
])

# %%
#SVC
svc_pipeline= Pipeline([
    ('preprocessor', num_pipeline),
    ('model', SVC())
])

# %%
#KNN
knn_pipeline= Pipeline([
    ('preprocessor', num_pipeline),
    ('model', KNeighborsClassifier())
])

# %%
#Naive Bayes
nb_pipeline= Pipeline([
    ('preprocessor', num_pipeline),
    ('model', GaussianNB())
])

# %%
#Decision Tree
dt_pipeline= Pipeline([
    ('preprocessor', tree_pipeline),
    ('model', DecisionTreeClassifier(random_state=124,
                                     max_depth=8,
                                     min_samples_leaf=10,
                                     min_samples_split=20))
])

# %%
#Random Forest
rf_pipeline= Pipeline([
    ('preprocessor', tree_pipeline),
    ('model', RandomForestClassifier(random_state=124, 
                                    n_estimators=300,
                                    max_depth=10,
                                    min_samples_leaf=5))
])

# %%
#XG Boost
xgb_pipeline= Pipeline([
    ('preprocessor', tree_pipeline),
    ('model', XGBClassifier(random_state=124,
                            n_estimators=300,
                            learning_rate=0.05,
                            max_depth=5))
])

# %%
#training models

lr_pipeline.fit(X_train, y_train)
nb_pipeline.fit(X_train, y_train)
knn_pipeline.fit(X_train, y_train)
svc_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['tenure', 'MonthlyCharges',
#                                                    'TotalCharges']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['gender', 'SeniorCitizen',
#                                                    'Partner', 'Dependents',
#                                                    'PhoneService',
#                                                    'MultipleLines',
#                                                    'InternetService',
#                                                    'OnlineSecurity',
#                                                    'OnlineBackup',
#                                                    'DeviceProtection',
#                                                    'TechSupport', 'StreamingTV',
#                                                    'StreamingMovies',
#                                                    'Contract',
#                                                    'PaperlessBilling',
#                                                    'PaymentMethod'])])),
#                 ('model', SVC())])

# %%
dt_pipeline.fit(X_train, y_train)
rf_pipeline.fit(X_train, y_train)
xgb_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', 'passthrough',
#                                                   ['tenure', 'MonthlyCharges',
#                                                    'TotalCharges']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['gender', 'SeniorCitizen',
#                                                    'Partner', 'Dependents',
#                                                    'PhoneService',
#                                                    'MultipleLines',
#                                                    'InternetService',
#                                                    'OnlineSecurity',
#                                                    'OnlineBackup',
#                                                    'DeviceProtection',
#                                                    'TechSupport', 'StreamingTV...
#                                feature_types=None, feature_weights=None,
#                                gamma=None, grow_policy=None,
#                                importance_type=None,
#                                interaction_constraints=None, learning_rate=0.05,
#                                max_bin=None, max_cat_threshold=None,
#                                max_cat_to_onehot=None, max_delta_step=None,
#                                max_depth=5, max_leaves=None,
#                                min_child_weight=None, missing=nan,
#                                monotone_constraints=None, multi_strategy=None,
#                                n_estimators=300, n_jobs=None,
#                                num_parallel_tree=None, ...))])

# %%
#predictions

lr_pred= lr_pipeline.predict(X_test)
nb_pred= nb_pipeline.predict(X_test)
knn_pred= knn_pipeline.predict(X_test)
svc_pred= svc_pipeline.predict(X_test)

dt_pred= dt_pipeline.predict(X_test)
rf_pred= rf_pipeline.predict(X_test)
xgb_pred= xgb_pipeline.predict(X_test)

# %%
#importing libraries
from sklearn.metrics import accuracy_score,classification_report, confusion_matrix, roc_auc_score

# %%
from sklearn.metrics import roc_curve


models={
    "Logistic Regression": lr_pred,
    "KNN": knn_pred,
    "SVM": svc_pred,
    "Decision Tree": dt_pred,
    "Random Forest": rf_pred,
    "XG Boost": xgb_pred
}

for name , pred in models.items():
    
    accuracy= accuracy_score(y_test, pred)
    
    print(f"{name}")
    print(f"Accuracy: {accuracy}")
    print("Confusion Matrix:")
    print(confusion_matrix(y_test, pred))
    print("Classification Report:")
    print(classification_report(y_test, pred))
    print('roc_auc_score')
    print(roc_auc_score(y_test, pred))
    print("-"*40)
# Out:
# Logistic Regression
# Accuracy: 0.8107852412488175
# Confusion Matrix:
# [[699  59]
#  [141 158]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.92      0.87       758
#            1       0.73      0.53      0.61       299
#
#     accuracy                           0.81      1057
#    macro avg       0.78      0.73      0.74      1057
# weighted avg       0.80      0.81      0.80      1057
#
# roc_auc_score
# 0.7252958410179932
# ----------------------------------------
# KNN
# Accuracy: 0.7682119205298014
# Confusion Matrix:
# [[658 100]
#  [145 154]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.87      0.84       758
#            1       0.61      0.52      0.56       299
#
#     accuracy                           0.77      1057
#    macro avg       0.71      0.69      0.70      1057
# weighted avg       0.76      0.77      0.76      1057
#
# roc_auc_score
# 0.6915620229260243
# ----------------------------------------
# SVM
# Accuracy: 0.804162724692526
# Confusion Matrix:
# [[719  39]
#  [168 131]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.95      0.87       758
#            1       0.77      0.44      0.56       299
#
#     accuracy                           0.80      1057
#    macro avg       0.79      0.69      0.72      1057
# weighted avg       0.80      0.80      0.78      1057
#
# roc_auc_score
# 0.6933379514829555
# ----------------------------------------
# Decision Tree
# Accuracy: 0.7890255439924314
# Confusion Matrix:
# [[688  70]
#  [153 146]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.91      0.86       758
#            1       0.68      0.49      0.57       299
#
#     accuracy                           0.79      1057
#    macro avg       0.75      0.70      0.71      1057
# weighted avg       0.78      0.79      0.78      1057
#
# roc_auc_score
# 0.6979730147104244
# ----------------------------------------
# Random Forest
# Accuracy: 0.8088930936613056
# Confusion Matrix:
# [[713  45]
#  [157 142]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.94      0.88       758
#            1       0.76      0.47      0.58       299
#
#     accuracy                           0.81      1057
#    macro avg       0.79      0.71      0.73      1057
# weighted avg       0.80      0.81      0.79      1057
#
# roc_auc_score
# 0.707774816671226
# ----------------------------------------
# XG Boost
# Accuracy: 0.8032166508987701
# Confusion Matrix:
# [[699  59]
#  [149 150]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.92      0.87       758
#            1       0.72      0.50      0.59       299
#
#     accuracy                           0.80      1057
#    macro avg       0.77      0.71      0.73      1057
# weighted avg       0.79      0.80      0.79      1057
#
# roc_auc_score
# 0.7119179145965884
# ----------------------------------------

# %%
preprocessor = lr_pipeline.named_steps['preprocessor']

# %%
feature_names = preprocessor.get_feature_names_out()

# %%
coefficients = lr_pipeline.named_steps['model'].coef_[0]

# %%
coef_df = pd.DataFrame({
    'Feature': feature_names,
    'Coefficient': coefficients
})

coef_df['Importance'] = abs(coef_df['Coefficient'])

coef_df = coef_df.sort_values(
    by='Importance',
    ascending=False
)

print(coef_df.head(20))
# Out:
#                                        Feature  Coefficient  Importance
# 0                                  num__tenure    -1.438842    1.438842
# 39                      cat__Contract_Two year    -0.745134    0.745134
# 2                            num__TotalCharges     0.710658    0.710658
# 37                cat__Contract_Month-to-month     0.532513    0.532513
# 16                    cat__InternetService_DSL    -0.371201    0.371201
# 12                       cat__PhoneService_Yes    -0.310580    0.310580
# 21                     cat__OnlineSecurity_Yes    -0.290207    0.290207
# 40                    cat__PaperlessBilling_No    -0.274649    0.274649
# 30                        cat__TechSupport_Yes    -0.262120    0.262120
# 13                       cat__MultipleLines_No    -0.250245    0.250245
# 17            cat__InternetService_Fiber optic     0.240371    0.240371
# 5                         cat__SeniorCitizen_0    -0.231083    0.231083
# 45             cat__PaymentMethod_Mailed check    -0.229828    0.229828
# 44         cat__PaymentMethod_Electronic check     0.226937    0.226937
# 10                         cat__Dependents_Yes    -0.175398    0.175398
# 1                          num__MonthlyCharges     0.173294    0.173294
# 24                       cat__OnlineBackup_Yes    -0.167002    0.167002
# 19                      cat__OnlineSecurity_No     0.159376    0.159376
# 43  cat__PaymentMethod_Credit card (automatic)    -0.155339    0.155339
# 4                             cat__gender_Male    -0.150993    0.150993

# %%
# Selected Features

selected_features = [
    'tenure',
    'Contract',
    'TotalCharges',
    'InternetService',
    'OnlineSecurity',
    'PaperlessBilling',
    'TechSupport',
    'MultipleLines',
    'PaymentMethod',
    'MonthlyCharges'
]

X_selected = X[selected_features]
y_selected = y

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_selected,
    y_selected,
    test_size=0.2,
    random_state=124
)

# %%
num_cols = [
    'tenure',
    'TotalCharges',
    'MonthlyCharges'
]

cat_cols = [
    'Contract',
    'InternetService',
    'OnlineSecurity',
    'PaperlessBilling',
    'TechSupport',
    'MultipleLines',
    'PaymentMethod'
]

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder

preprocessor = ColumnTransformer([
    ('num', StandardScaler(), num_cols),
    ('cat', OneHotEncoder(handle_unknown='ignore'), cat_cols)
])

# %%
from sklearn.linear_model import LogisticRegression

lr_pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('model', LogisticRegression(
        random_state=124,
        max_iter=1000
    ))
])

lr_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['tenure', 'TotalCharges',
#                                                    'MonthlyCharges']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['Contract',
#                                                    'InternetService',
#                                                    'OnlineSecurity',
#                                                    'PaperlessBilling',
#                                                    'TechSupport',
#                                                    'MultipleLines',
#                                                    'PaymentMethod'])])),
#                 ('model', LogisticRegression(max_iter=1000, random_state=124))])

# %%
from sklearn.ensemble import RandomForestClassifier

rf_pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('model', RandomForestClassifier(
        random_state=124,
        n_estimators=300,
        max_depth=10
    ))
])

rf_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['tenure', 'TotalCharges',
#                                                    'MonthlyCharges']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['Contract',
#                                                    'InternetService',
#                                                    'OnlineSecurity',
#                                                    'PaperlessBilling',
#                                                    'TechSupport',
#                                                    'MultipleLines',
#                                                    'PaymentMethod'])])),
#                 ('model',
#                  RandomForestClassifier(max_depth=10, n_estimators=300,
#                                         random_state=124))])

# %%
from xgboost import XGBClassifier

xgb_pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('model', XGBClassifier(
        random_state=124,
        n_estimators=300,
        learning_rate=0.05,
        max_depth=5,
        eval_metric='logloss'
    ))
])

xgb_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['tenure', 'TotalCharges',
#                                                    'MonthlyCharges']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['Contract',
#                                                    'InternetService',
#                                                    'OnlineSecurity',
#                                                    'PaperlessBilling',
#                                                    'TechSupport',
#                                                    'MultipleLines',
#                                                    'PaymentMethod'])])),
#                 ('model',
#                  XGBClassifier(base_score=None, booster=None, cal...
#                                feature_types=None, feature_weights=None,
#                                gamma=None, grow_policy=None,
#                                importance_type=None,
#                                interaction_constraints=None, learning_rate=0.05,
#                                max_bin=None, max_cat_threshold=None,
#                                max_cat_to_onehot=None, max_delta_step=None,
#                                max_depth=5, max_leaves=None,
#                                min_child_weight=None, missing=nan,
#                                monotone_constraints=None, multi_strategy=None,
#                                n_estimators=300, n_jobs=None,
#                                num_parallel_tree=None, ...))])

# %%
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    classification_report,
    roc_auc_score
)

def evaluate_model(name, model):

    y_pred = model.predict(X_test)

    if hasattr(model, "predict_proba"):
        y_prob = model.predict_proba(X_test)[:,1]
    else:
        y_prob = None

    print(f"\n{name}")

    print("Accuracy:")
    print(accuracy_score(y_test, y_pred))

    print("\nConfusion Matrix:")
    print(confusion_matrix(y_test, y_pred))

    print("\nClassification Report:")
    print(classification_report(y_test, y_pred))

    if y_prob is not None:
        print("\nROC AUC:")
        print(roc_auc_score(y_test, y_prob))

    print("-"*50)

# %%
evaluate_model("Logistic Regression", lr_pipeline)
evaluate_model("Random Forest", rf_pipeline)
evaluate_model("XGBoost", xgb_pipeline)
# Out:
# Logistic Regression
# Accuracy:
# 0.8218594748048261
#
# Confusion Matrix:
# [[951  84]
#  [167 207]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.92      0.88      1035
#            1       0.71      0.55      0.62       374
#
#     accuracy                           0.82      1409
#    macro avg       0.78      0.74      0.75      1409
# weighted avg       0.81      0.82      0.81      1409
#
#
# ROC AUC:
# 0.8616058281019918
# --------------------------------------------------
#
# Random Forest
# Accuracy:
# 0.8126330731014905
#
# Confusion Matrix:
# [[952  83]
#  [181 193]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.92      0.88      1035
#            1       0.70      0.52      0.59       374
#
#     accuracy                           0.81      1409
#    macro avg       0.77      0.72      0.74      1409
# weighted avg       0.80      0.81      0.80      1409
#
#
# ROC AUC:
# 0.8558500607093957
# --------------------------------------------------
#
# XGBoost
# Accuracy:
# 0.8119233498935415
#
# Confusion Matrix:
# [[953  82]
#  [183 191]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.92      0.88      1035
#            1       0.70      0.51      0.59       374
#
#     accuracy                           0.81      1409
#    macro avg       0.77      0.72      0.73      1409
# weighted avg       0.80      0.81      0.80      1409
#
#
# ROC AUC:
# 0.8569337880079567
# --------------------------------------------------

# %%
#model deployment
import joblib

joblib.dump(lr_pipeline, 'churn_model.pkl')
# Out:
# ['churn_model.pkl']

# %%
#saving the cleaned dataset
cleaned_df= df.to_csv('cleaned_churn_data.csv', index=False)
